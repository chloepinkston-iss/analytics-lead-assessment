# %% [markdown]
# # 📊 ISS STOXX — Analytics Lead Assessment
# ## Deriving Financial Insights
#
# This starter notebook loads the provided datasets and includes structure for all required parts of the assessment.
#
# **Datasets:**
# - `transcripts_25_tickers_2022_2024.csv`
# - `structured_financials_clean.csv`
#
# ---
# # Part 1 — Data Processing
# Load, clean, explore, and join the datasets.

# %%
import pandas as pd
import numpy as np

transcripts = pd.read_csv('../data/transcripts_25_tickers_2022_2024.csv')
financials = pd.read_csv('../data/structured_financials_clean.csv')

transcripts.head(), financials.head()

# %% [markdown]
# ## Basic Exploration & Cleaning
# Inspect shapes, columns, missing values, and verify ticker alignment.

# %%
transcripts['symbol'].value_counts()

# %% [markdown]
# ## Derived Features (At least two)
# Examples: revenue growth, margins, sentiment, etc.

# %%
# Example placeholder feature
financials['revenue_growth'] = financials.groupby('ticker')['revenue'].pct_change()
financials.head()

# %% [markdown]
# # Part 2 — NLP / Text Analysis
# Apply sentiment, topic modeling, or other NLP techniques. Explain your reasoning.

# %% [markdown]
# # Part 2B — Optional Modeling
# Build simple predictive models if time allows.

# %% [markdown]
# # Part 3 — Data Modeling & Pipeline Design
# Define fact/dimension tables, grain, and transformations.

# %% [markdown]
# # Part 4 — Dashboard (Power BI or Tableau)
# Document/chart key insights from your dashboard.

# %% [markdown]
# # Part 5 — Write-Up
# Summaries, insights, limitations, next steps.
